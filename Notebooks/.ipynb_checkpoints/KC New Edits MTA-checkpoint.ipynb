# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as mat
import datetime as dt
sys.path.append('../src')
import mta_data_clean as mc

# %%
# Read the datafiles
data_path = '../data/'
pickle_file = 'mta_data.pickle'
'''
data_file_list = ['turnstile_191102.txt',
                 'turnstile_191109.txt',
                 'turnstile_191116.txt',
                 'turnstile_191130.txt',
                 'turnstile_191207.txt',
                 'turnstile_191214.txt',
                 'turnstile_191221.txt',
                 'turnstile_191228.txt'
                 'turnstile_200104.txt']
'''
data_file_list = ['turnstile_191102.txt',
                 'turnstile_191005.txt']
booth_key_filename = 'Remote-Booth-Station.csv'

# %%
df = mc.mta_data_pickle_read(pickle_file)

# %%
df.describe()
# Out:
#             entries         exits     deltaEntry      deltaExit
# count  2.060460e+05  2.060460e+05  206046.000000  206046.000000
# mean   4.101341e+07  3.395214e+07     161.158644     127.948560
# std    2.113375e+08  1.958360e+08     261.822016     244.203327
# min    0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    2.987312e+05  1.387082e+05       0.000000       0.000000
# 50%    1.969911e+06  1.157290e+06      40.000000      31.000000
# 75%    6.621930e+06  4.505968e+06     220.000000     148.000000
# max    2.129010e+09  2.123659e+09   12526.000000   10727.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206046 entries, 0 to 206045
# Data columns (total 10 columns):
# station       206046 non-null object
# division      206046 non-null object
# date          206046 non-null datetime64[ns]
# time          206046 non-null object
# desc          206046 non-null object
# entries       206046 non-null int64
# exits         206046 non-null int64
# weekday       206046 non-null object
# deltaEntry    206046 non-null int64
# deltaExit     206046 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 15.7+ MB

# %%
top_stations = df.sort_values('deltaEntry', ascending = False).groupby('station').head(1)
top_stations['station'].unique()
# Out:
# array(['JOURNAL SQUARE', 'GRD CNTRL-42 ST', '59 ST COLUMBUS',
#        '14 ST-UNION SQ', '34 ST-HERALD SQ', 'WOODHAVEN BLVD', '111 ST',
#        'FOREST HILLS 71', '57 ST-7 AV', '30 AV', '47-50 STS ROCK',
#        'YORK ST', '34 ST-PENN STA', 'SPRING ST', '42 ST-PORT AUTH',
#        'LEXINGTON AV/53', 'BEDFORD AV', 'TIMES SQ-42 ST', '23 ST',
#        '8 ST-NYU', 'PATH NEW WTC', 'W 4 ST-WASH SQ', '42 ST-BRYANT PK',
#        '14 ST', '59 ST', 'FRANKLIN AV', '125 ST', '149/GRAND CONC',
#        'CHAMBERS ST', 'CANAL ST', 'NOSTRAND AV', 'BOROUGH HALL',
#        'PAVONIA/NEWPORT', '86 ST-2 AVE', 'BROADWAY', 'PARKCHESTER',
#        'CITY / BUS', 'FULTON ST', 'TWENTY THIRD ST', '68ST-HUNTER CO',
#        'THIRTY ST', '86 ST', 'GROVE STREET', '116 ST-COLUMBIA',
#        'FLUSHING-MAIN', 'JAMAICA CENTER', 'DEKALB AV', '96 ST', '5 AVE',
#        'KEW GARDENS', "B'WAY-LAFAYETTE", 'JAY ST-METROTEC', '28 ST',
#        'GRAHAM AV', 'MORISN AV/SNDVW', 'LEXINGTON AV/63', '8 AV',
#        'VERNON-JACKSON', '72 ST-2 AVE', '5 AV/53 ST', 'CANARSIE-ROCKAW',
#        '34 ST-HUDSON YD', '21 ST-QNSBRIDGE', '1 AV', 'THIRTY THIRD ST',
#        '40 ST LOWERY ST', 'GATES AV', '168 ST', '50 ST', 'PRINCE ST',
#        'CHURCH AV', 'MYRTLE-WYCKOFF', 'HOUSTON ST', 'GRAND-NEWTOWN',
#        '14TH STREET', 'ASTORIA DITMARS', 'GRAND ST', 'GRANT AV',
#        'HIGH ST', '145 ST', '103 ST-CORONA', 'MYRTLE AV',
#        'JKSN HT-ROOSVLT', 'BOWLING GREEN', 'CHRISTOPHER ST',
#        'JUNCTION BLVD', '2 AV', 'WORLD TRADE CTR', 'QUEENSBORO PLZ',
#        'FLATBUSH AV-B.C', '7 AV', '49 ST', '157 ST', 'MARCY AV',
#        '61 ST WOODSIDE', 'WALL ST', 'JAMAICA 179 ST', '3 AV-149 ST',
#        'UTICA AV', '18 ST', 'UNION ST', 'ALLERTON AV', 'FOREST AVE',
#        'NEWKIRK PLAZA', 'NEWKIRK AV', '90 ST-ELMHURST', 'ROOSEVELT ISLND',
#        'CRESCENT ST', 'HALSEY ST', '9TH STREET', 'PROSPECT PARK',
#        'DYCKMAN ST', 'CARROLL ST', 'WHITEHALL S-FRY', 'HOYT-SCHER',
#        'PELHAM PKWY', 'FT HAMILTON PKY', '103 ST', '36 ST',
#        'KINGSBRIDGE RD', 'QUEENS PLAZA', 'ELDER AV', '72 ST',
#        'NORTHERN BLVD', 'LACKAWANNA', '77 ST', 'BEDFORD-NOSTRAN',
#        'SHEEPSHEAD BAY', 'ATL AV-BARCLAY', '82 ST-JACKSON H',
#        'BROOKLYN BRIDGE', 'KINGSTON-THROOP', 'EUCLID AV', 'SIMPSON ST',
#        'RECTOR ST', 'PROSPECT AV', '116 ST', '5 AV/59 ST',
#        '66 ST-LINCOLN', 'PARKSIDE AV', 'BAY PKWY', '45 ST', 'CLASSON AV',
#        'BAYCHESTER AV', 'CLINTON-WASH AV', 'CROWN HTS-UTICA',
#        'ELMHURST AV', 'STEINWAY ST', '25 AV', 'PELHAM BAY PARK',
#        'GRAND ARMY PLAZ', '110 ST', '33 ST', '57 ST', 'PARK PLACE',
#        'WINTHROP ST', 'HARRISON', 'E 180 ST', 'DELANCEY/ESSEX',
#        'MONTROSE AV', '36 AV', 'SOUTH FERRY', '174 ST', '18 AV', '181 ST',
#        '3 AV 138 ST', 'CONEY IS-STILLW', '96 ST-2 AVE', '46 ST', '231 ST',
#        'AVENUE U', '51 ST', 'BAY RIDGE AV', 'WTC-CORTLANDT',
#        'CORTELYOU RD', 'NORWOOD 205 ST', 'NASSAU AV', 'COURT SQ-23 ST',
#        '88 ST', 'COURT SQ', 'BERGEN ST', 'FLUSHING AV', 'NEW LOTS',
#        '33 ST-RAWSON ST', 'SUTTER AV', '52 ST', '233 ST', 'STERLING ST',
#        'INWOOD-207 ST', 'BRIGHTON BEACH', '46 ST BLISS ST', '238 ST',
#        '137 ST CITY COL', 'CENTRAL AV', '135 ST', 'TREMONT AV',
#        'EASTCHSTER/DYRE', 'FORDHAM RD', 'CITY HALL', 'CLEVELAND ST',
#        'BLEECKER ST', '63 DR-REGO PARK', '175 ST', 'KOSCIUSZKO ST',
#        'EAST BROADWAY', '3 AV', 'CATHEDRAL PKWY', '167 ST', 'BUHRE AV',
#        'METROPOLITAN AV', '81 ST-MUSEUM', '67 AV', 'BROAD ST', 'CLARK ST',
#        'CORTLANDT ST', 'BROADWAY JCT', 'ASTOR PL', 'JFK JAMAICA CT1',
#        'MORRIS PARK', 'KINGS HWY', 'EXCHANGE PLACE', 'LORIMER ST',
#        'V.CORTLANDT PK', 'FRANKLIN ST', '170 ST', 'HUNTS POINT AV',
#        '53 ST', 'GUN HILL RD', 'FRESH POND RD', 'JEFFERSON ST',
#        'BRIARWOOD', '4AV-9 ST', '20 AV', 'NEVINS ST', '225 ST',
#        'RALPH AV', 'SUTPHIN-ARCHER', 'KNICKERBOCKER', 'NEWARK C', '6 AV',
#        '191 ST', 'BEDFORD PK BLVD', 'WILSON AV', 'NEWARK BM BW', '79 ST',
#        '161/YANKEE STAD', 'CENTRAL PK N110', 'OZONE PK LEFFRT',
#        'PRESIDENT ST', 'MYRTLE-WILLOUGH', 'CASTLE HILL AV', 'ST. GEORGE',
#        '75 AV', 'KINGSTON AV', 'MARBLE HILL-225', 'JAMAICA VAN WK',
#        'BURNSIDE AV', '25 ST', '80 ST', 'NEREID AV', 'RIT-MANHATTAN',
#        'E 149 ST', '190 ST', 'NECK RD', 'ROCKAWAY BLVD', 'JACKSON AV',
#        'BAY RIDGE-95 ST', 'BEVERLY RD', 'WOODLAWN', 'BOWERY',
#        'FREEMAN ST', 'GREENPOINT AV', 'BURKE AV', '183 ST', '9 AV',
#        '219 ST', 'BEVERLEY ROAD', 'LAFAYETTE AV', 'SMITH-9 ST', 'HOYT ST',
#        'RIT-ROOSEVELT', 'AVENUE X', 'SHEPHERD AV', 'NORWOOD AV',
#        'BAY 50 ST', 'WESTCHESTER SQ', 'DITMAS AV', 'ZEREGA AV', '39 AV',
#        'WAKEFIELD/241', '182-183 STS', 'LIVONIA AV', 'SUTTER AV-RUTLD',
#        'EAST 105 ST', '155 ST', 'VAN SICLEN AV', 'ST LAWRENCE AV',
#        '15 ST-PROSPECT', 'BROOK AV', 'PATH WTC 2', 'BRONX PARK EAST',
#        'ROCKAWAY AV', '85 ST-FOREST PK', '71 ST', 'MORGAN AV',
#        'MOSHOLU PKWY', 'INTERVALE AV', '163 ST-AMSTERDM', '65 ST',
#        'VAN SICLEN AVE', 'LIBERTY AV', 'EASTN PKWY-MUSM', 'CHAUNCEY ST',
#        'HUNTERS PT AV', '207 ST', 'SARATOGA AV', 'SENECA AVE',
#        'NEW LOTS AV', '74 ST-BROADWAY', 'NEWARK HW BMEBE',
#        '75 ST-ELDERTS', 'PENNSYLVANIA AV', 'AVENUE N', '176 ST',
#        'MT EDEN AV', 'HARLEM 148 ST', 'WEST FARMS SQ', '169 ST',
#        'BOTANIC GARDEN', 'BEACH 90 ST', '138/GRAND CONC', 'PARSONS BLVD',
#        '4 AV-9 ST', 'SUTPHIN BLVD', 'LONGWOOD AV', 'CYPRESS AV',
#        'AVENUE P', 'BUSHWICK AV', 'NEPTUNE AV', 'FAR ROCKAWAY',
#        '174-175 STS', '104 ST', 'AVENUE M', 'BEACH 25 ST', 'ALABAMA AV',
#        'MIDDLETOWN RD', 'BEACH 67 ST', '21 ST', 'BEACH 60 ST', '69 ST',
#        'HEWES ST', 'AVENUE J', 'WHITLOCK AV', 'AVENUE I', 'NEWARK HM HE',
#        '55 ST', 'NEW UTRECHT AV', 'CYPRESS HILLS', 'AVENUE H',
#        "E 143/ST MARY'S", 'AQUEDUCT RACETR', 'HOWARD BCH JFK',
#        'OCEAN PKWY', 'W 8 ST-AQUARIUM', 'JUNIUS ST', 'METS-WILLETS PT',
#        '215 ST', 'ATLANTIC AV', 'AQUEDUCT N.COND', '121 ST',
#        'BEACH 36 ST', 'BEACH 44 ST', 'ROCKAWAY PARK B', 'BROAD CHANNEL',
#        'BEACH 98 ST', 'TOMPKINSVILLE', 'BEACH 105 ST'], dtype=object)

# %%
pv_weekday = pd.pivot_table(df, values=['deltaEntry','deltaExit'], index = ['weekday', 'station'],aggfunc=[np.max])
pv_weekday
# Out:
#                                 amax
#                           deltaEntry deltaExit
# weekday   station
# Friday    1 AV                  1315      1973
#           103 ST                1174       950
#           103 ST-CORONA         1329      1418
#           104 ST                 326       214
#           110 ST                1004       876
# ...                              ...       ...
# Wednesday WOODLAWN               682       288
#           WORLD TRADE CTR       1166      1447
#           WTC-CORTLANDT          920       679
#           YORK ST               2191      2114
#           ZEREGA AV              610       410
#
# [2639 rows x 2 columns]

# %%
deltaEntry_sorted = df.sort_values('deltaEntry', ascending = False).groupby('station').head(1)
deltaEntry_sorted.head(20)
# Out:
#                 station division       date      time     desc     entries  \
# 117354   JOURNAL SQUARE      PTH 2019-10-29  14:09:40  REGULAR       12527
# 160451  GRD CNTRL-42 ST      IRT 2019-10-29  20:00:00  REGULAR     3507920
# 50581    59 ST COLUMBUS      IND 2019-10-29  20:00:00  REGULAR    14366186
# 4967     14 ST-UNION SQ      BMT 2019-10-29  21:00:00  REGULAR    17234555
# 3165    34 ST-HERALD SQ      BMT 2019-10-28  20:00:00  REGULAR    27861519
# 84804    WOODHAVEN BLVD      IND 2019-10-30  09:00:00  REGULAR     4287029
# 190006           111 ST      IRT 2019-10-26  12:00:00  REGULAR    17207252
# 86644   FOREST HILLS 71      IND 2019-10-30  13:00:00  REGULAR     3698524
# 1463         57 ST-7 AV      BMT 2019-10-30  20:00:00  REGULAR     2826589
# 185494            30 AV      BMT 2019-10-30  12:00:00  REGULAR     1968768
# 95748    47-50 STS ROCK      IND 2019-10-28  20:00:00  REGULAR     7374367
# 103627          YORK ST      IND 2019-10-29  21:00:00  REGULAR    15845926
# 137039   34 ST-PENN STA      IRT 2019-10-29  10:00:00  REGULAR    23298077
# 58294         SPRING ST      IND 2019-10-29  20:00:00  REGULAR   341982427
# 53489   42 ST-PORT AUTH      IND 2019-10-31  12:00:00  REGULAR     4412527
# 79384   LEXINGTON AV/53      IND 2019-11-01  20:00:00  REGULAR   740245887
# 32985        BEDFORD AV      BMT 2019-10-29  12:00:00  REGULAR    11651603
# 139781   TIMES SQ-42 ST      IRT 2019-10-30  20:00:00  REGULAR  1719434805
# 56315             23 ST      IND 2019-10-28  20:00:00  REGULAR       49839
# 6107           8 ST-NYU      BMT 2019-10-30  20:00:00  REGULAR      896522
#
#             exits    weekday  deltaEntry  deltaExit
# 117354      10727    Tuesday       12526      10727
# 160451     401888    Tuesday        3146         13
# 50581     1959387    Tuesday        2974        128
# 4967      6911037    Tuesday        2727        176
# 3165     11586683     Monday        2697        642
# 84804     1599323  Wednesday        2563         45
# 190006   11519164   Saturday        2453         26
# 86644      108107  Wednesday        2385         40
# 1463       352893  Wednesday        2341         88
# 185494     214846  Wednesday        2328         18
# 95748     3803736     Monday        2322        161
# 103627   26303487    Tuesday        2252        529
# 137039   12228010    Tuesday        2245         67
# 58294    85287329    Tuesday        2215        123
# 53489     1965329   Thursday        2209        143
# 79384   572150651     Friday        2187        211
# 32985     2404196    Tuesday        2147        183
# 139781  320408374  Wednesday        2146        174
# 56315       14857     Monday        2044         97
# 6107        40812  Wednesday        2039         58

# %%
deltaExit_sorted = df.sort_values('deltaExit', ascending = False).groupby(['station']).head(1)

top20_stations = deltaExit_sorted.head(20) ## top 20 rows of whichever sorted variable we choose (Entry or Exit)
station_names = top20_stations['station'].unique() ## top 20 station names

top_20_df = df[df['station'].isin(station_names)] ## filters dataframe for the top 20 station names

another_df = top_20_df.sort_values('deltaExit', ascending = False).groupby(['time']).head(1)

pd.pivot_table(another_df, values = 'deltaExit', index = ['weekday','time'], aggfunc = [np.max])
# Out:
#                         amax
#                    deltaExit
# weekday   time
# Friday    00:00:00         0
#           00:00:18         0
#           00:01:32         0
#           00:12:39         0
#           00:20:23         0
# ...                      ...
# Wednesday 23:45:40        18
#           23:50:04       151
#           23:51:42        81
#           23:53:00        37
#           23:58:11         8
#
# [3793 rows x 1 columns]

# %%
top20_pivot = pd.pivot_table(top_20_df, values=['deltaEntry','deltaExit'], index = ['weekday', 'time'],aggfunc=[np.max])
top20_pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-8b0e8ddadc61> in <module>
#       1 top20_pivot = pd.pivot_table(top_20_df, values=['deltaEntry','deltaExit'], index = ['weekday', 'time'],aggfunc=[np.max])
# ----> 2 top20_pivot.sort_values('deltaEntry', ascending = False)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'deltaEntry'

# %%
time_group = df.sort_values('deltaEntry', ascending = False).groupby(['station']).head(1)
time_group.groupby(['weekday']).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ab531adf5d9> in <module>
# ----> 1 time_group = df.sort_values('deltaEntry', ascending = False).groupby(['station']).head(1)
#       2 time_group.groupby(['weekday']).head(1)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Pivot Table by Weekday -- deltaEntry / deltaExit

# %%
pd.pivot_table(df, index = 'weekday',values = ['deltaEntry','deltaExit'], aggfunc =[np.max, np.sum])
# Out:
#                 amax                  sum
#           deltaEntry deltaExit deltaEntry deltaExit
# weekday
# Friday          2912      4045    5643386   4461153
# Monday          2934      4440    5566061   4356304
# Saturday        2453      2148    2977580   2475033
# Sunday          1637      1337    1955742   1673531
# Thursday        2868      3972    5519465   4355196
# Tuesday        12526     10727    5766178   4507601
# Wednesday       2944      4443    5777682   4534471

# %%
station1 = top_20_df[top_20_df['station'] == '34 ST-HERALD SQ']
pd.pivot_table(station1, index = 'weekday',values = ['deltaEntry','deltaExit'], aggfunc =[np.max, np.sum])
# Out:
#                 amax                  sum
#           deltaEntry deltaExit deltaEntry deltaExit
# weekday
# Friday          2569      3087     106687    114119
# Monday          2697      3066     102815    108208
# Saturday        1414      1838      56369     66436
# Sunday          1046      1300      39368     46439
# Thursday        2449      2818     101232    104405
# Tuesday         2616      3240     105311    112062
# Wednesday       2600      3203     106389    110824

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-138da7cb9607> in <module>
# ----> 1 df.groupby(['station']).sort_values('deltaEntry')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'sort_values' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %% [markdown]
# ### Pivot Table by Station with Sum of Delta Entry by Weekday

# %%
pd.pivot_table(top_20_df, index= 'station', columns= 'weekday', values= 'deltaEntry', aggfunc = [np.sum])
# Out:
#                     sum
# weekday          Friday  Monday Saturday Sunday Thursday Tuesday Wednesday
# station
# 14 ST-UNION SQ    94522   91704    58789  34668    92707   93133     97159
# 34 ST-HERALD SQ  106687  102815    56369  39368   101232  105311    106389
# 34 ST-HUDSON YD   28354   18875    14859   7536    22806   18653     18196
# 34 ST-PENN STA   159922  160294    75770  61803   156872  165332    165436
# 42 ST-PORT AUTH   86472   83648    51147  41973    85977   89732     88119
# 5 AV/53 ST        29226   27602       32      3    28083   31238     29659
# 5 AVE             12441   11734     5455   3087    11942   12903     12244
# 59 ST             61992   61088    39143  24156    60425   63696     63807
# 86 ST             84636   82916    49332  30085    84923   87182     87121
# 96 ST             64036   62930    35912  24479    64118   65418     66693
# ATL AV-BARCLAY    41994   41198    35608  22589    39946   42009     42957
# CHAMBERS ST       56997   61004    21199  11456    59345   63603     62338
# GRD CNTRL-42 ST  132751  137673    53097  39225   138235  151145    144610
# JOURNAL SQUARE    28042   27534    14756   8401    28398   40605     28314
# NEWARK HM HE       2868    2346        0      0     2011    2603      2366
# PATH NEW WTC      54060   59993     2670   1408    57351   62010     62055
# PATH WTC 2         2415    2487      116    102     2207    2924      2816
# TIMES SQ-42 ST    84801   81463    45041  32665    81708   85462     86672
# TWENTY THIRD ST    9346    9314     4165   2607     9525   10228      9951
# W 4 ST-WASH SQ    40610   36253    30572  20268    35269   37956     38411

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# use Seaborn styles
sns.set()
pd.pivot_table(top_20_df, index= 'station', columns= 'weekday', values= 'deltaEntry').plot(kind= 'bar')
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %%
deltaExit_sorted.describe()
# Out:
#             entries         exits    deltaEntry     deltaExit
# count  3.770000e+02  3.770000e+02    377.000000    377.000000
# mean   3.164982e+07  3.388765e+07    253.533156    976.557029
# std    1.969654e+08  2.040872e+08    661.367281    894.073232
# min    1.000000e+00  3.060000e+02      0.000000      0.000000
# 25%    5.830700e+05  9.448360e+05     84.000000    450.000000
# 50%    2.722627e+06  4.527317e+06    167.000000    747.000000
# 75%    6.253092e+06  9.550954e+06    307.000000   1248.000000
# max    1.999962e+09  1.979864e+09  12526.000000  10727.000000

# %%
df[df['station']].sample(20)
# Out:
#                 station division       date      time     desc   entries  \
# 161070  GRD CNTRL-42 ST      IRT 2019-10-27  01:00:00  REGULAR   8741536
# 161294  GRD CNTRL-42 ST      IRT 2019-10-29  09:00:00  REGULAR   6278210
# 160503  GRD CNTRL-42 ST      IRT 2019-10-31  04:00:00  REGULAR    228923
# 160205  GRD CNTRL-42 ST      IRT 2019-11-01  12:00:00  REGULAR        28
# 160848  GRD CNTRL-42 ST      IRT 2019-11-01  01:00:00  REGULAR   7333763
# 160778  GRD CNTRL-42 ST      IRT 2019-10-27  09:00:00  REGULAR   1710039
# 158422  GRD CNTRL-42 ST      IRT 2019-10-29  13:00:00  REGULAR    937989
# 160658  GRD CNTRL-42 ST      IRT 2019-10-28  09:00:00  REGULAR   1248897
# 158427  GRD CNTRL-42 ST      IRT 2019-10-30  09:00:00  REGULAR    939378
# 159920  GRD CNTRL-42 ST      IRT 2019-10-27  00:00:00  REGULAR         0
# 159616  GRD CNTRL-42 ST      IRT 2019-11-01  08:00:00  REGULAR     78019
# 158879  GRD CNTRL-42 ST      IRT 2019-10-28  16:00:00  REGULAR   1335095
# 160265  GRD CNTRL-42 ST      IRT 2019-10-28  08:47:16  REGULAR    157030
# 158541  GRD CNTRL-42 ST      IRT 2019-10-28  09:00:00  REGULAR  12447875
# 158776  GRD CNTRL-42 ST      IRT 2019-11-01  13:00:00  REGULAR   8623790
# 159832  GRD CNTRL-42 ST      IRT 2019-10-26  08:00:00  REGULAR  37674659
# 160705  GRD CNTRL-42 ST      IRT 2019-10-29  05:00:00  REGULAR    141741
# 159489  GRD CNTRL-42 ST      IRT 2019-11-01  04:00:00  REGULAR   2509013
# 158559  GRD CNTRL-42 ST      IRT 2019-10-31  09:00:00  REGULAR  12450045
# 159503  GRD CNTRL-42 ST      IRT 2019-10-27  12:00:00  REGULAR    966741
#
#            exits    weekday  deltaEntry  deltaExit
# 161070   2454511     Sunday           0          0
# 161294   4056767    Tuesday         118       1111
# 160503      8632   Thursday          43         12
# 160205        46     Friday           0          0
# 160848  11276378     Friday           0          0
# 160778   2359349     Sunday           0          1
# 158422   1890656    Tuesday         143        784
# 160658   1655719     Monday          49       2340
# 158427   1892656  Wednesday          67        667
# 159920      1068     Sunday           0          0
# 159616     98745     Friday          20        115
# 158879   3763684     Monday          27         63
# 160265     29322     Monday         466          0
# 158541  13882575     Monday         216         18
# 158776   5359179     Friday         778       1138
# 159832   9824924   Saturday           6        237
# 160705    211972    Tuesday          58         11
# 159489   2803728     Friday          11         69
# 158559  13882994   Thursday         226         25
# 159503   1508894     Sunday          22        255

# %% [markdown]
# ### Filtering df for Weekdays

# %%
weekdays = ['Monday','Tuesday','Wednesday','Thursday','Friday']
top20_weekday_df = top_20_df[top_20_df['weekday'].isin(weekdays)]
top20_weekday_df['weekday'].unique()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
#       dtype=object)

# %% [markdown]
# ### Trying to plot the deltaEntry by station by weekday

# %%
sns.set()
pd.pivot_table(top20_weekday_df, index= 'station', columns= 'weekday', values= 'deltaEntry').plot(kind= 'bar')
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %%
sns.set()
pd.pivot_table(top20_weekday_df, index= 'station', columns= 'weekday', values= 'deltaExit').plot(kind= 'bar')
plt.ylabel("Number")
plt.figure(figsize=(40, 30))

# %%
y_val = top20_weekday_df['deltaEntry']
plt.plot(y_val)

# %% [markdown]
# ### Boxplot of weekday vs. deltaExit

# %%
import matplotlib.pyplot as plt
cols = ['weekday','deltaExit']
data_box = top20_weekday_df[cols]
ax = sns.boxplot(x='weekday', y='deltaExit', data=top20_weekday_df)
plt.ylim(0, 5000)
# Out:
# (0, 5000)

# %%
tuesday_data = top20_weekday_df[top20_weekday_df['weekday'] == 'Tuesday']
tues_box = sns.distplot(top20_weekday_df['deltaExit'])

# %%
plt.plot(,y_val,kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-87332d9425cf> in <module>
# ----> 1 plt.plot(weekdays,y_val,kind='bar')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (23940,)
